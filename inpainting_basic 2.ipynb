# %%
# %matplotlib inline
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('group.png')
mask = cv.imread('s4.jpeg',0)
dst = cv.inpaint(img,mask,3,cv.INPAINT_NS)

# %%
plt.imshow(dst)
plt.show()
